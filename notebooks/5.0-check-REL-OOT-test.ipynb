# %%
import os

import ast
from ast import literal_eval
import requests
import sqlalchemy
import psycopg2
from sqlalchemy import create_engine

import pandas as pd
from tqdm import tqdm


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)

# %%
def main(
    dataset: pd.DataFrame,
    title: str = "title",
    article: str = "article",
):

    dataset = dataset
    annotated_articles = []

    for index, row in tqdm(dataset.iterrows(), total=dataset.shape[0]):

        if len(row[title].split()) > 3300 or len(row[article].split()) > 3300:
            continue

        # Perform mention detection on headline and body text
        el_title = requests.post(API_URL, json={
            "text": row[title],
            "spans": []
        }).json()
        el_article = requests.post(API_URL, json={
            "text": row[article],
            "spans": []
        }).json()

        # Filter mentions with the ORG tag
        headline_mentions_org = [
            mention for mention in el_title if mention[-1] == "ORG"
        ]
        body_text_mentions_org = [
            mention for mention in el_article if mention[-1] == "ORG"
        ]

        # Mark salient entities
        salient_entities_org = []
        for body_entity in body_text_mentions_org:
            if body_entity[3] in [
                headline_entity[3] for headline_entity in headline_mentions_org
            ]:
                salient_entities_org.append(body_entity)

        if salient_entities_org:
            salient_entities_org_set = set([entity[3] for entity in salient_entities_org])
        else:
            salient_entities_org_set = {'None'}
            
        # Save the annotated article
        annotated_articles.append(
            {
                "headline": row[title],
                "body_text": row[article],
                "headline_mentions": el_title,
                "body_text_mentions": el_article,
                "salient_entities_org": salient_entities_org,
                "salient_entities_set": salient_entities_org_set,
            }
        )

    return pd.DataFrame(annotated_articles)

# %%
API_URL = "http://rel:5555/api"

# %% [markdown]
# # Load parsed news from DB and save for labeling

# %%
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')
db_user = os.getenv('DB_USER')
db_pass = os.getenv('DB_PASS')

# %%
# Create the connection string
connection_str = f'postgresql://{db_user}:{db_pass}@{db_host}:{db_port}/{db_name}'

# Create the engine
engine = create_engine(connection_str)

# %%
query = 'SELECT * FROM raw_news_articles'
df = pd.read_sql(query, engine)

# %%
df.head()
# Out:
#    id                                              title  \
# 0   1  Starting at $60,990, Tesla's Cybertruck is pri...
# 1   2  Read Linda Yaccarino’s message to X employees ...
# 2   3  Disney Reinstates Dividend, Amends Bylaws Amid...
# 3   4  From affordability to property demand, here ar...
# 4   5  Dow Jones Hits 2023 High As Salesforce Soars; ...
#
#                                                 text  \
# 0  Nov 30 (Reuters) - Tesla's (TSLA.O) long-delay...
# 1  Linda Yaccarino sent a memo to employees of X ...
# 2  Disney today announced a cash dividend of $0.3...
# 3  High mortgage rate and home prices sidelined m...
# 4                                               None
#
#                publish_date publish_date_source  \
# 0 2023-11-30 00:00:00+00:00              parsed
# 1 2023-11-30 00:00:00+00:00              parsed
# 2 2023-11-30 22:10:15+00:00              parsed
# 3 2023-11-30 00:00:00+00:00              parsed
# 4                       NaT                None
#
#                                              authors  \
# 0  [Akash Sriram Hyunjoo Jin Abhirup Roy, Akash S...
# 1                              [Jonathan Vanian, In]
# 2                                   [Jill Goldsmith]
# 3                                       [Phil Rosen]
# 4                                               None
#
#                                       canonical_link  \
# 0  https://www.reuters.com/business/autos-transpo...
# 1  https://www.cnbc.com/2023/11/30/read-linda-yac...
# 2  https://deadline.com/2023/11/disney-reinstates...
# 3  https://markets.businessinsider.com/news/commo...
# 4                                               None
#
#                                            feed_link  \
# 0  https://news.google.com/rss/articles/CBMie2h0d...
# 1  https://news.google.com/rss/articles/CBMiZmh0d...
# 2  https://news.google.com/rss/articles/CBMiaWh0d...
# 3  https://news.google.com/rss/articles/CBMihQFod...
# 4  https://news.google.com/rss/articles/CBMijgFod...
#
#                             media_link                media_title  is_parsed  \
# 0              https://www.reuters.com                    Reuters       True
# 1                 https://www.cnbc.com                       CNBC       True
# 2                 https://deadline.com                   Deadline       True
# 3  https://markets.businessinsider.com            Markets Insider       True
# 4            https://www.investors.com  Investor's Business Daily      False
#
#     exception_class                                     exception_text  \
# 0              None                                               None
# 1              None                                               None
# 2              None                                               None
# 3              None                                               None
# 4  ArticleException  Article `download()` failed with 403 Client Er...
#
#                                             url_hash        date_created
# 0  83bc522d93ce214c43182256b8f805b46a5c2d39f214d4... 2023-12-01 06:05:36
# 1  63329ae2128c913d54235a98b155a792c49b8adad89d59... 2023-12-01 06:05:38
# 2  694a1ed27646c306ab80db39a68cb48f3d1e1f8ca90e15... 2023-12-01 06:05:39
# 3  69e1ad3a026abd7ed076ba72aa18884568238cfb0a23ab... 2023-12-01 06:05:41
# 4  03cedd18dd1facb6574b7a241aa689a6401b63a6653a15... 2023-12-01 06:05:42

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7302 entries, 0 to 7301
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   7302 non-null   int64
#  1   title                7302 non-null   object
#  2   text                 4751 non-null   object
#  3   publish_date         4751 non-null   datetime64[ns, UTC]
#  4   publish_date_source  4751 non-null   object
#  5   authors              4751 non-null   object
#  6   canonical_link       4751 non-null   object
#  7   feed_link            7302 non-null   object
#  8   media_link           7302 non-null   object
#  9   media_title          7302 non-null   object
#  10  is_parsed            7302 non-null   bool
#  11  exception_class      2551 non-null   object
#  12  exception_text       2551 non-null   object
#  13  url_hash             7302 non-null   object
#  14  date_created         7302 non-null   datetime64[ns]
# dtypes: bool(1), datetime64[ns, UTC](1), datetime64[ns](1), int64(1), object(11)
# memory usage: 805.9+ KB

# %%
len(set(df['url_hash'].values))
# Out:
# 6786

# %%
len(set(df['feed_link'].values))
# Out:
# 5636

# %%
len(set(df['canonical_link'].values))
# Out:
# 4316

# %%
len(set(df['title'].values))
# Out:
# 5578

# %%
len(set(df['text'].values))
# Out:
# 4409

# %%
len(set(df['publish_date'].values))
# Out:
# 4934

# %%
len(set(df[df['is_parsed'] == True]['url_hash'].values))
# Out:
# 4363

# %%
len(set(df[df['is_parsed'] == True]['canonical_link'].values))
# Out:
# 4315

# %%
df['canonical_link'].value_counts()
# Out:
# canonical_link
# https://www.foxnews.com/us/most-unsafe-cities-holiday-season-research-shows                                                                          4
# https://finance.yahoo.com/news/stock-market-news-today-stocks-on-six-week-win-streak-after-strong-jobs-report-210913952.html                         4
# https://www.foxbusiness.com/real-estate/real-estate-investor-warns-us-entering-greatest-correction-lifetime                                          3
# https://www.cbsnews.com/news/ozempic-counterfeit-fda-seizes-thousands-novo-nordisk/                                                                  3
# https://finance.yahoo.com/news/stock-market-news-today-dow-hits-record-high-as-stocks-cap-longest-weekly-winning-streak-since-2017-181200723.html    3
#                                                                                                                                                     ..
# https://www.nytimes.com/2023/12/08/business/economy/jobs-report-november-2023.html                                                                   1
# https://www.washingtonpost.com/technology/2023/12/08/open-ai-sam-altman-complaints/                                                                  1
# https://www.cnbc.com/2023/12/08/exxon-mobil-is-one-of-the-most-oversold-names-and-could-be-primed-for-a-bounce-here-are-the-others.html              1
# https://www.cnbc.com/2023/12/08/the-runway-is-getting-clearer-but-the-us-economy-still-isnt-assured-of-a-soft-landing.html                           1
# https://hackaday.com/2023/12/25/the-tech-that-died-in-2023/                                                                                          1
# Name: count, Length: 4315, dtype: int64

# %%
df[df['canonical_link'] == 'https://www.foxnews.com/us/most-unsafe-cities-holiday-season-research-shows']
# Out:
#         id                                              title  \
# 5492  6895  These are the most 'unsafe' cities during the ...
# 6989  6988  The 10 most ‘unsafe’ cities during the holiday...
# 7154  7155  These are the most 'unsafe' cities during the ...
# 7221  7221  The 10 most ‘unsafe’ cities during the holiday...
#
#                                                    text  \
# 5492  The following cities ranked among the top 10 m...
# 6989  The following cities ranked among the top 10 m...
# 7154  Read this article for free! Plus get unlimited...
# 7221  The following cities ranked among the top 10 m...
#
#                   publish_date publish_date_source           authors  \
# 5492 2023-12-24 09:00:00+00:00        approximated  [Audrey Conklin]
# 6989 2023-12-24 00:00:00+00:00              parsed                []
# 7154 2023-12-24 09:00:00+00:00        approximated  [Audrey Conklin]
# 7221 2023-12-24 00:00:00+00:00              parsed                []
#
#                                          canonical_link  \
# 5492  https://www.foxnews.com/us/most-unsafe-cities-...
# 6989  https://www.foxnews.com/us/most-unsafe-cities-...
# 7154  https://www.foxnews.com/us/most-unsafe-cities-...
# 7221  https://www.foxnews.com/us/most-unsafe-cities-...
#
#                                               feed_link  \
# 5492  https://news.google.com/rss/articles/CBMiS2h0d...
# 6989  https://news.google.com/rss/articles/CBMiTWh0d...
# 7154  https://news.google.com/rss/articles/CBMiS2h0d...
# 7221  https://news.google.com/rss/articles/CBMiTWh0d...
#
#                    media_link    media_title  is_parsed exception_class  \
# 5492  https://www.foxnews.com       Fox News       True            None
# 6989       https://nypost.com  New York Post       True            None
# 7154  https://www.foxnews.com       Fox News       True            None
# 7221       https://nypost.com  New York Post       True            None
#
#      exception_text                                           url_hash  \
# 5492           None  878e3e2dde967480c6ab048cdf4cf4b4974f5864d77921...
# 6989           None  26dc3749cbe4113c4ed8943c286ea3f0f341b87ff5a56f...
# 7154           None  878e3e2dde967480c6ab048cdf4cf4b4974f5864d77921...
# 7221           None  26dc3749cbe4113c4ed8943c286ea3f0f341b87ff5a56f...
#
#             date_created
# 5492 2023-12-24 11:05:44
# 6989 2023-12-24 20:05:39
# 7154 2023-12-25 15:05:59
# 7221 2023-12-25 21:05:22

# %%
df['url_hash'].value_counts()
# Out:
# url_hash
# 2c828d4c2b4e5daabae76ca2b588229c89a92f69f2ab7e57ded644590c058bb4    5
# 7073  2c828d4c2b4e5daabae76ca2b588229c89a92f69f2ab7e... 2023-12-25 04:05:05

# %%
df['title'].value_counts()[:20]
# Out:
# title
# Fed Chair Powell's Comments Spark Cross-Asset Rally, Upend 2024 Outlooks - Bloomberg       42
# BlackRock, State Street Subpoenaed in House ESG Probe - Bloomberg                          35
# Citi Exiting Distressed-Debt Trading in Latest Retrenchment - Bloomberg                    27
# Nvidia Sees Vietnam as Potential Second Home, Reports Say - Bloomberg                      27
# Heathrow Airport: How Saudi Arabia May Ultimately Gain Control - Bloomberg                 25
# Modi's Resounding State Polls Win Fuels India Market Rally - Bloomberg                     24
# Toyota Halts Some SE Asia Exports on Daihatsu Scandal: Yomiuri - Bloomberg                 24
# Apple to Drop Goldman Sachs for Apple Card; Chase Bank Is Ideal Replacement - Bloomberg    21
# Byju's Founder Pledges Homes to Raise Funds for Staff Salaries - Bloomberg                 20
# A-Rod's Slam SPAC Is Said to Plan Merger With Lynk Global - Bloomberg                      19
# Used Car Prices Drop As Negative Equity Slams Buyers - Bloomberg                           19
# Starbucks Heads for Record Losing Streak as Sales Concerns Build - Bloomberg               19
# This Is Why We Didn't Have a Recession in 2023 - Bloomberg                                 19
# Why Signa's Lofty Property Valuations Are Bad News for Its Creditors - Bloomberg           18
# Fed Chair Powell's Comments on Interest Rate Cuts Fuels Market Euphoria - Bloomberg        18
# COP28 Boosts Carbon Capture, a Long Shot Fix for the Climate - Bloomberg                   18
# China Frames 'One Province, One Policy' Plan for Financial Risk - Bloomberg                17
# Stock Market Today: Dow, S&P Live Updates for December 5 - Bloomberg                       16
# Germany's Bayer Says it Won a Roundup Cancer Trial in California - Bloomberg               16
# Zuckerberg Sells First Meta Shares in Two Years After 172% Surge - Bloomberg               16
# Name: count, dtype: int64

# %%
df[df['title'] == "Fed Chair Powell's Comments Spark Cross-Asset Rally, Upend 2024 Outlooks - Bloomberg"]
# Out:
#         id                                              title  text  \
# 2794  4589  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 3211  4602  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 3413  4660  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 3456  4615  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 3772  4629  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4011  4674  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4483  4645  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4530  4436  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4540  4472  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4542  4447  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4552  4457  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4577  4484  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4590  4497  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4599  4506  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4601  4529  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4608  4514  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4637  4541  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4670  4577  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4699  4686  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4720  4701  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4735  4716  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4746  4726  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4756  4737  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4769  4750  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4780  4760  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4796  4774  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4806  4778  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4818  4789  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4825  4796  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4834  4806  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4840  4812  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4848  4820  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4862  4833  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4869  4861  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4875  4845  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4897  4869  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4909  4880  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4926  4894  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4936  4906  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4947  4917  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4954  4924  Fed Chair Powell's Comments Spark Cross-Asset ...  None
# 4965  4936  Fed Chair Powell's Comments Spark Cross-Asset ...  None
#
#      publish_date publish_date_source authors canonical_link  \
# 2794          NaT                None    None           None
# 3211          NaT                None    None           None
# 3413          NaT                None    None           None
# 3456          NaT                None    None           None
# 3772          NaT                None    None           None
# 4011          NaT                None    None           None
# 4483          NaT                None    None           None
# 4530          NaT                None    None           None
# 4540          NaT                None    None           None
# 4542          NaT                None    None           None
# 4552          NaT                None    None           None
# 4577          NaT                None    None           None
# 4590          NaT                None    None           None
# 4926  https://news.google.com/rss/articles/CBMic2h0d...
# 4936  https://news.google.com/rss/articles/CBMic2h0d...
# 4947  https://news.google.com/rss/articles/CBMic2h0d...
# 4954  https://news.google.com/rss/articles/CBMic2h0d...
# 4965  https://news.google.com/rss/articles/CBMic2h0d...
#
#                      media_link media_title  is_parsed exception_class  \
# 2794  https://www.bloomberg.com   Bloomberg      False      ValueError
# 3211  https://www.bloomberg.com   Bloomberg      False      ValueError
# 3413  https://www.bloomberg.com   Bloomberg      False      ValueError
# 3456  https://www.bloomberg.com   Bloomberg      False      ValueError
# 3772  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4011  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4483  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4530  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4540  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4542  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4552  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4577  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4590  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4599  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4601  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4608  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4637  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4670  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4699  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4720  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4735  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4746  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4756  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4769  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4780  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4796  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4806  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4818  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4825  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4834  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4840  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4848  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4862  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4869  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4875  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4897  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4909  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4926  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4936  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4947  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4954  https://www.bloomberg.com   Bloomberg      False      ValueError
# 4965  https://www.bloomberg.com   Bloomberg      False      ValueError
#
#                                          exception_text  \
# 2794  Essential fields are empty, possibly due to bo...
# 3211  Essential fields are empty, possibly due to bo...
# 3413  Essential fields are empty, possibly due to bo...
# 3456  Essential fields are empty, possibly due to bo...
# 3772  Essential fields are empty, possibly due to bo...
# 4011  Essential fields are empty, possibly due to bo...
# 4483  Essential fields are empty, possibly due to bo...
# 4530  Essential fields are empty, possibly due to bo...
# 4540  Essential fields are empty, possibly due to bo...
# 4542  Essential fields are empty, possibly due to bo...
# 4552  Essential fields are empty, possibly due to bo...
# 4577  Essential fields are empty, possibly due to bo...
# 4590  Essential fields are empty, possibly due to bo...
# 4599  Essential fields are empty, possibly due to bo...
# 4601  Essential fields are empty, possibly due to bo...
# 4608  Essential fields are empty, possibly due to bo...
# 4637  Essential fields are empty, possibly due to bo...
# 4670  Essential fields are empty, possibly due to bo...
# 4699  Essential fields are empty, possibly due to bo...
# 4720  Essential fields are empty, possibly due to bo...
# 4735  Essential fields are empty, possibly due to bo...
# 4746  Essential fields are empty, possibly due to bo...
# 4756  Essential fields are empty, possibly due to bo...
# 4769  Essential fields are empty, possibly due to bo...
# 4780  Essential fields are empty, possibly due to bo...
# 4796  Essential fields are empty, possibly due to bo...
# 4806  Essential fields are empty, possibly due to bo...
# 4818  Essential fields are empty, possibly due to bo...
# 4825  Essential fields are empty, possibly due to bo...
# 4834  Essential fields are empty, possibly due to bo...
# 4840  Essential fields are empty, possibly due to bo...
# 4848  Essential fields are empty, possibly due to bo...
# 4862  Essential fields are empty, possibly due to bo...
# 4869  Essential fields are empty, possibly due to bo...
# 4875  Essential fields are empty, possibly due to bo...
# 4897  Essential fields are empty, possibly due to bo...
# 4909  Essential fields are empty, possibly due to bo...
# 4926  Essential fields are empty, possibly due to bo...
# 4936  Essential fields are empty, possibly due to bo...
# 4947  Essential fields are empty, possibly due to bo...
# 4954  Essential fields are empty, possibly due to bo...
# 4965  Essential fields are empty, possibly due to bo...
#
#                                                url_hash        date_created
# 2794  73a2d05f38fcee2f65828f54f71ba0424082b5a87aaec1... 2023-12-16 15:05:16
# https://news.google.com/rss/articles/CBMibWh0dHBzOi8vd3d3LmtpdGNvLmNvbS9uZXdzLzIwMjMtMTItMDgvU3Ryb25nLWxvc3Nlcy1mb3ItZ29sZC1zaWx2ZXItZm9sbG93aW5nLWdvbGRpbG9ja3MtVS1TLWpvYnMtcmVwb3J0Lmh0bWzSAQA?oc=5                                                                              1
# https://news.google.com/rss/articles/CBMiT2h0dHBzOi8vdG9vZmFiLmNvbS8yMDIzLzEyLzA4L2p1ZGdlLXNlbnRlbmNlLXdvbWFuLWNoaXBvdGxlLXdvcmstYWZ0ZXItYXNzYXVsdC_SAQA?oc=5                                                                                                                      1
# https://news.google.com/rss/articles/CCAiC2loRkxVOEVYWmFjmAEB?oc=5                                                                                                                                                                                                                 1
# https://news.google.com/rss/articles/CBMiO2h0dHBzOi8vaGFja2FkYXkuY29tLzIwMjMvMTIvMjUvdGhlLXRlY2gtdGhhdC1kaWVkLWluLTIwMjMv0gEA?oc=5                                                                                                                                                 1
# Name: count, Length: 5636, dtype: int64

# %%
start = "You are an investor who reads financial and business news. There may be many companies mentioned in the news, but not all of them are affected by the news. You want to understand which companies in the news are really affected by the news from an investor's point of view. I'll send you the headline and body of the news and you extract only the companies important to the news in the format ['Company1', 'Company2']"
end = " | ATTENTION!!! I DON’T WANT YOU ADVICES HOW TO DO IT!!!! REMEMBER YOU HAVE TO EXTRACT the salient companies as [‘Company1’, 'Company2’] (this is example of format) keeping in mind you are an investor who has filtered a list of news on a particular company. You want to see only those news that can really affect the company. REMEMBER FORMAT [‘Company1’, 'Company2’]!!!!!!!"
# Out:
# /opt/conda/lib/python3.11/site-packages/IPython/core/inputtransformer2.py:627: UserWarning: `make_tokens_by_line` received a list of lines which do not have lineending markers ('\n', '\r', '\r\n', '\x0b', '\x0c'), behavior will be unspecified
#   tokens_by_line = make_tokens_by_line(lines)

# %%
df = df[df['is_parsed'] == True]

df['query'] = start + ' | HEADLINE: ' + df['title'] + ' | BODYTEXT: ' + df['text'] + end
df = df[['id', 'url_hash', 'title', 'text', 'query']]
df.head()
# Out:
#    id                                           url_hash  \
# 0   1  83bc522d93ce214c43182256b8f805b46a5c2d39f214d4...
# 1   2  63329ae2128c913d54235a98b155a792c49b8adad89d59...
# 2   3  694a1ed27646c306ab80db39a68cb48f3d1e1f8ca90e15...
# 3   4  69e1ad3a026abd7ed076ba72aa18884568238cfb0a23ab...
# 5   6  7dacd5458df4eb9d566c52b14ab1d59cf10ce37f0822e6...
#
#                                                title  \
# 0  Starting at $60,990, Tesla's Cybertruck is pri...
# 1  Read Linda Yaccarino’s message to X employees ...
# 2  Disney Reinstates Dividend, Amends Bylaws Amid...
# 3  From affordability to property demand, here ar...
# 5  S&P 500’s Historic 8.9% Rally Blindsides Skept...
#
#                                                 text  \
# 0  Nov 30 (Reuters) - Tesla's (TSLA.O) long-delay...
# 1  Linda Yaccarino sent a memo to employees of X ...
# 2  Disney today announced a cash dividend of $0.3...
# 3  High mortgage rate and home prices sidelined m...
# 5  (Bloomberg) -- The US stock market just posted...
#
#                                                query
# 0  You are an investor who reads financial and bu...
# 1  You are an investor who reads financial and bu...
# 2  You are an investor who reads financial and bu...
# 3  You are an investor who reads financial and bu...
# 5  You are an investor who reads financial and bu...

# %%
df.to_excel('raw_news_articles_202312141455.xlsx', index=False)

# %% [markdown]
# # Load test data (hand labeled)

# %%
df_test = pd.read_excel('target_raw_news_articles_202312141455.xlsx')
df_test = df_test[~df_test['target'].isna()]
df_test['target'] = df_test['target'].apply(lambda x: x.strip("[]").replace("'", ""))
df_test.shape
# Out:
# (148, 6)

# %%
df_test.head()
# Out:
#    id                                           url_hash  \
# 0   1  83bc522d93ce214c43182256b8f805b46a5c2d39f214d4...
# 1   2  63329ae2128c913d54235a98b155a792c49b8adad89d59...
# 2   3  694a1ed27646c306ab80db39a68cb48f3d1e1f8ca90e15...
# 3   4  69e1ad3a026abd7ed076ba72aa18884568238cfb0a23ab...
# 4   6  7dacd5458df4eb9d566c52b14ab1d59cf10ce37f0822e6...
#
#                                                title  \
# 0  Starting at $60,990, Tesla's Cybertruck is pri...
# 1  Read Linda Yaccarino’s message to X employees ...
# 2  Disney Reinstates Dividend, Amends Bylaws Amid...
# 3  From affordability to property demand, here ar...
# 4  S&P 500’s Historic 8.9% Rally Blindsides Skept...
#
#                                                 text  \
# 0  Nov 30 (Reuters) - Tesla's (TSLA.O) long-delay...
# 1  Linda Yaccarino sent a memo to employees of X ...
# 2  Disney today announced a cash dividend of $0.3...
# 3  High mortgage rate and home prices sidelined m...
# 4  (Bloomberg) -- The US stock market just posted...
#
#                                                query                target
# 0  You are an investor who reads financial and bu...                 Tesla
# 1  You are an investor who reads financial and bu...  X (formerly Twitter)
# 2  You are an investor who reads financial and bu...                Disney
# 3  You are an investor who reads financial and bu...                Zillow
# 4  You are an investor who reads financial and bu...                  None

# %% [markdown]
# # Bring the target to the REL form

# %%
def simple_REL(text):
    el_result = requests.post(API_URL, json={
        "text": text,
        "spans": []
    }).json()
    
    mentions = [
            mention for mention in el_result if mention[-1] == "ORG"
        ]
    salient_entities = {'None'}
    if mentions:
        salient_entities = set([entity[3] for entity in mentions])
        
    return salient_entities

# %%
df_test['target_formatted'] = df_test['target'].apply(simple_REL)

# %%
df_test.head()
# Out:
#    id                                           url_hash  \
# 0   1  83bc522d93ce214c43182256b8f805b46a5c2d39f214d4...
# 1   2  63329ae2128c913d54235a98b155a792c49b8adad89d59...
# 2   3  694a1ed27646c306ab80db39a68cb48f3d1e1f8ca90e15...
# 3   4  69e1ad3a026abd7ed076ba72aa18884568238cfb0a23ab...
# 4   6  7dacd5458df4eb9d566c52b14ab1d59cf10ce37f0822e6...
#
#                                                title  \
# 0  Starting at $60,990, Tesla's Cybertruck is pri...
# 1  Read Linda Yaccarino’s message to X employees ...
# 2  Disney Reinstates Dividend, Amends Bylaws Amid...
# 3  From affordability to property demand, here ar...
# 4  S&P 500’s Historic 8.9% Rally Blindsides Skept...
#
#                                                 text  \
# 0  Nov 30 (Reuters) - Tesla's (TSLA.O) long-delay...
# 1  Linda Yaccarino sent a memo to employees of X ...
# 2  Disney today announced a cash dividend of $0.3...
# 3  High mortgage rate and home prices sidelined m...
# 4  (Bloomberg) -- The US stock market just posted...
#
#                                                query                target  \
# 0  You are an investor who reads financial and bu...                 Tesla
# 1  You are an investor who reads financial and bu...  X (formerly Twitter)
# 2  You are an investor who reads financial and bu...                Disney
# 3  You are an investor who reads financial and bu...                Zillow
# 4  You are an investor who reads financial and bu...                  None
#
#             target_formatted
# 0              {Tesla,_Inc.}
# 1                  {Twitter}
# 2  {The_Walt_Disney_Company}
# 3                   {Zillow}
# 4                     {None}

# %%
df_test_rel = main(df_test, 'title', 'text')
df_test_rel.shape
# Out:
# 100%|██████████| 148/148 [06:01<00:00,  2.44s/it]
# (148, 6)

# %%
df_test_rel.head()
# Out:
#                                             headline  \
# 0  Starting at $60,990, Tesla's Cybertruck is pri...
# 1  Read Linda Yaccarino’s message to X employees ...
# 2  Disney Reinstates Dividend, Amends Bylaws Amid...
# 3  From affordability to property demand, here ar...
# 4  S&P 500’s Historic 8.9% Rally Blindsides Skept...
#
#                                            body_text  \
# 0  Nov 30 (Reuters) - Tesla's (TSLA.O) long-delay...
# 1  Linda Yaccarino sent a memo to employees of X ...
# 2  Disney today announced a cash dividend of $0.3...
# 3  High mortgage rate and home prices sidelined m...
# 4  (Bloomberg) -- The US stock market just posted...
#
#                                    headline_mentions  \
# 0  [[21, 5, Tesla, Tesla,_Inc., 0.591238980628300...
# 1  [[52, 9, Elon Musk, Elon_Musk, 0.3872777678067...
# 2                                                 []
# 3  [[48, 6, Zillow, Zillow, 0.3872777678067984, 0...
# 4  [[53, 11, Wall Street, Wall_Street, 0.93163738...
#
#                                   body_text_mentions  \
# 0  [[19, 5, Tesla, Tesla,_Inc., 0.664780689106363...
# 1  [[56, 7, Twitter, Twitter, 0.9176650349707419,...
# 2  [[0, 6, Disney, Walt_Disney_Studios_(division)...
# 3  [[50, 9, Americans, United_States, 0.520198409...
# 4  [[1, 9, Bloomberg, Bloomberg_L.P., 0.838348418...
#
#                                 salient_entities_org salient_entities_set
# 0  [[19, 5, Tesla, Tesla,_Inc., 0.664780689106363...        {Tesla,_Inc.}
# 1  [[3094, 9, Elon Musk, Elon_Musk, 0.38727776780...          {Elon_Musk}
# 2                                                 []               {None}
# 3  [[94, 6, Zillow, Zillow, 0.3872777678067984, 0...             {Zillow}
# 4                                                 []               {None}

# %%
df_merged = df_test.merge(df_test_rel, how='outer', left_on='title', right_on='headline')
df_merged.head()
# Out:
#    id                                           url_hash  \
# 0   1  83bc522d93ce214c43182256b8f805b46a5c2d39f214d4...
# 1   2  63329ae2128c913d54235a98b155a792c49b8adad89d59...
# 2   3  694a1ed27646c306ab80db39a68cb48f3d1e1f8ca90e15...
# 3   4  69e1ad3a026abd7ed076ba72aa18884568238cfb0a23ab...
# 4   4  69e1ad3a026abd7ed076ba72aa18884568238cfb0a23ab...
#
#                                                title  \
# 0  Starting at $60,990, Tesla's Cybertruck is pri...
# 1  Read Linda Yaccarino’s message to X employees ...
# 2  Disney Reinstates Dividend, Amends Bylaws Amid...
# 3  From affordability to property demand, here ar...
# 4  From affordability to property demand, here ar...
#
#                                                 text  \
# 0  Nov 30 (Reuters) - Tesla's (TSLA.O) long-delay...
# 1  Linda Yaccarino sent a memo to employees of X ...
# 2  Disney today announced a cash dividend of $0.3...
# 3  High mortgage rate and home prices sidelined m...
# 4  High mortgage rate and home prices sidelined m...
#
#                                                query                target  \
# 0  You are an investor who reads financial and bu...                 Tesla
# 1  You are an investor who reads financial and bu...  X (formerly Twitter)
# 2  You are an investor who reads financial and bu...                Disney
# 3  You are an investor who reads financial and bu...                Zillow
# 4  You are an investor who reads financial and bu...                Zillow
#
#             target_formatted  \
# 0              {Tesla,_Inc.}
# 1                  {Twitter}
# 2  {The_Walt_Disney_Company}
# 3                   {Zillow}
# 4                   {Zillow}
#
#                                             headline  \
# 0  Starting at $60,990, Tesla's Cybertruck is pri...
# 1  Read Linda Yaccarino’s message to X employees ...
# 2  Disney Reinstates Dividend, Amends Bylaws Amid...
# 3  From affordability to property demand, here ar...
# 4  From affordability to property demand, here ar...
#
#                                            body_text  \
# 0  Nov 30 (Reuters) - Tesla's (TSLA.O) long-delay...
# 1  Linda Yaccarino sent a memo to employees of X ...
# 2  Disney today announced a cash dividend of $0.3...
# 3  High mortgage rate and home prices sidelined m...
# 4  AP Photo/John Raoux, File\n\nHigh mortgage rat...
#
#                                    headline_mentions  \
# 0  [[21, 5, Tesla, Tesla,_Inc., 0.591238980628300...
# 1  [[52, 9, Elon Musk, Elon_Musk, 0.3872777678067...
# 2                                                 []
# 3  [[48, 6, Zillow, Zillow, 0.3872777678067984, 0...
# 4  [[48, 6, Zillow, Zillow, 0.3872777678067984, 0...
#
#                                   body_text_mentions  \
# 0  [[19, 5, Tesla, Tesla,_Inc., 0.664780689106363...
# 1  [[56, 7, Twitter, Twitter, 0.9176650349707419,...
# 2  [[0, 6, Disney, Walt_Disney_Studios_(division)...
# 3  [[50, 9, Americans, United_States, 0.520198409...
# 4  [[77, 9, Americans, United_States, 0.495860628...
#
#                                 salient_entities_org salient_entities_set
# 0  [[19, 5, Tesla, Tesla,_Inc., 0.664780689106363...        {Tesla,_Inc.}
# 1  [[3094, 9, Elon Musk, Elon_Musk, 0.38727776780...          {Elon_Musk}
# 2                                                 []               {None}
# 3  [[94, 6, Zillow, Zillow, 0.3872777678067984, 0...             {Zillow}
# 4  [[121, 6, Zillow, Zillow, 0.3872777678067984, ...             {Zillow}

# %%
df_merged.shape
# Out:
# (156, 13)

# %%
df_diff = df_merged[df_merged['target_formatted'] != df_merged['salient_entities_set']]
df_diff.shape
# Out:
# (82, 13)

# %%
df_diff.head()
# Out:
#     id                                           url_hash  \
# 1    2  63329ae2128c913d54235a98b155a792c49b8adad89d59...
# 2    3  694a1ed27646c306ab80db39a68cb48f3d1e1f8ca90e15...
# 9    8  3113a30d9ee07a8cfd66424b4cf8eaa6f977021c844773...
# 15  13  2bfad57b81083d98472300f7934ac351cea4cf848e3f94...
# 16  14  4fb13e2ef5ff679e852834916229c11d0e4e6ca5f76278...
#
#                                                 title  \
# 1   Read Linda Yaccarino’s message to X employees ...
# 2   Disney Reinstates Dividend, Amends Bylaws Amid...
# 9   Meta AI Chief Yann LeCun On His Open Source Mi...
# 15  Meta Sues FTC, Says it Has No Constitutional R...
# 16  U.K. Opens Inquiry Into Jeff Zucker’s Emirati-...
#
#                                                  text  \
# 1   Linda Yaccarino sent a memo to employees of X ...
# 2   Disney today announced a cash dividend of $0.3...
# 9   In an exclusive interview leading up to the 10...
# 15  Meta is working all the angles it can to ensur...
# 16  Jeff Zucker’s re-entry into the global news bu...
#
#                                                 query  \
# 1   You are an investor who reads financial and bu...
# 2   You are an investor who reads financial and bu...
# 9   You are an investor who reads financial and bu...
# 15  You are an investor who reads financial and bu...
# 16  You are an investor who reads financial and bu...
#
#                                 target                      target_formatted  \
# 1                 X (formerly Twitter)                             {Twitter}
# 2                               Disney             {The_Walt_Disney_Company}
# 9                                 Meta                     {Meta_Department}
# 15                                Meta                     {Meta_Department}
# 16  The Daily Telegraph, The Spectator  {The_Spectator, The_Daily_Telegraph}
#
#                                              headline  \
# 1   Read Linda Yaccarino’s message to X employees ...
# 2   Disney Reinstates Dividend, Amends Bylaws Amid...
# 9   Meta AI Chief Yann LeCun On His Open Source Mi...
# 15  Meta Sues FTC, Says it Has No Constitutional R...
# 16  U.K. Opens Inquiry Into Jeff Zucker’s Emirati-...
#
#                                             body_text  \
# 1   Linda Yaccarino sent a memo to employees of X ...
# 2   Disney today announced a cash dividend of $0.3...
# 9   In an exclusive interview leading up to the 10...
# 15  Meta is working all the angles it can to ensur...
# 16  Jeff Zucker’s re-entry into the global news bu...
#
#                                     headline_mentions  \
# 1   [[52, 9, Elon Musk, Elon_Musk, 0.3872777678067...
# 2                                                  []
# 9   [[14, 10, Yann LeCun, Yann_LeCun, 0.3872777678...
# 15                                                 []
# 16  [[24, 11, Jeff Zucker, Jeff_Zucker, 0.38727776...
#
#                                    body_text_mentions  \
# 1   [[56, 7, Twitter, Twitter, 0.9176650349707419,...
# 2   [[0, 6, Disney, Walt_Disney_Studios_(division)...
# 9   [[79, 5, LeCun, Yann_LeCun, 0.3872777678067984...
# 15  [[0, 4, Meta, Wikimedia_Foundation, 0.23680703...
# 16  [[0, 11, Jeff Zucker, Jeff_Zucker, 0.387277767...
#
#                                  salient_entities_org   salient_entities_set
# 1   [[3094, 9, Elon Musk, Elon_Musk, 0.38727776780...            {Elon_Musk}
# 2                                                  []                 {None}
# 9                                                  []                 {None}
# 15                                                 []                 {None}
# 16  [[218, 19, The Daily Telegraph, The_Daily_Tele...  {The_Daily_Telegraph}

# %%
def evaluate_ner(dataset, target_col, pred_col):
    TP, FP, FN = 0, 0, 0

    # Iterate over each row in the dataset
    for index, row in dataset.iterrows():
        true_entities = row[target_col]
        pred_entities = row[pred_col]

        # Update counts
        TP += len(true_entities.intersection(pred_entities))
        FP += len(pred_entities - true_entities)
        FN += len(true_entities - pred_entities)

    # Calculate Precision, Recall, and F1 Score
    precision = TP / (TP + FP) if TP + FP != 0 else 0
    recall = TP / (TP + FN) if TP + FN != 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if precision + recall != 0 else 0

    return precision, recall, f1_score

# %%
precision, recall, f1_score = evaluate_ner(df_merged, 'target_formatted', 'salient_entities_set')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1_score:.2f}")
# Out:
# Precision: 0.63
# Recall: 0.36
# F1 Score: 0.46

# %%
# Example dataset
data = {
    'predicted': [{"Moscow", "Paris"}, {"New York"}],  # Predicted entities here
    'targets': [{"Moscow", "Paris", "London"}, {"New York", "Boston"}]  # True entities here
}
dataset = pd.DataFrame(data)

precision, recall, f1_score = evaluate_ner(dataset, 'targets', 'predicted')
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1_score:.2f}")

# %%
for row in df_merged.iterrows():
    print(f"{row[1][2][:10]} | {row[1][6]} | {row[1][-1]}")
# Out:
# Starting a | {'Tesla,_Inc.'} | {'Tesla,_Inc.'}
# Read Linda | {'Twitter'} | {'Elon_Musk'}
# Disney Rei | {'The_Walt_Disney_Company'} | {'None'}
# From affor | {'Zillow'} | {'Zillow'}
# From affor | {'Zillow'} | {'Zillow'}
# From affor | {'Zillow'} | {'Zillow'}
# From affor | {'Zillow'} | {'Zillow'}
# S&P 500’s  | {'None'} | {'None'}
# Some OPEC+ | {'OPEC'} | {'OPEC'}
# Meta AI Ch | {'Meta_Department'} | {'None'}
# OpenAI ten | {'OpenAI'} | {'OpenAI'}
# How OpenAI | {'OpenAI'} | {'OpenAI'}
# UiPath Inc | {'None'} | {'None'}
# Asia facto | {'None'} | {'None'}
# The Fed’s  | {'Federal_Reserve'} | {'Federal_Reserve'}
# Meta Sues  | {'Meta_Department'} | {'None'}
# U.K. Opens | {'The_Spectator', 'The_Daily_Telegraph'} | {'The_Daily_Telegraph'}
# Stock mark | {'OPEC'} | {'None'}
# Stock mark | {'OPEC'} | {'None'}
# Stock mark | {'OPEC'} | {'None'}
# Stock mark | {'OPEC'} | {'None'}
# PDD earnin | {'Alibaba_Group', 'Pinduoduo', 'Pinky_Dinky_Doo'} | {'Alibaba_Group'}
# JPMorgan C | {'JPMorgan_Chase'} | {'JPMorgan_Chase'}
# Mortgage r | {'None'} | {'None'}
# Precut can | {'Sprouts_Farmers_Market', 'Kroger'} | {'Centers_for_Disease_Control_and_Prevention'}
# Ford says  | {'General_Motors', 'Ford_Motor_Company'} | {'United_Automobile_Workers', 'Ford_Motor_Company'}
# Salesforce | {'None'} | {'Salesforce.com'}
# Top 50 Big | {'Willkie_Farr_&amp;_Gallagher'} | {'None'}
# Biotech st | {'Daiichi_Sankyo', 'Sutro_Biopharma', 'ImmunoGen', 'Pfizer', 'SeaGen', 'Merck_&amp;_Co.', 'AbbVie_Inc.'} | {'ImmunoGen', 'AbbVie_Inc.'}
# Generative | {'OpenAI', 'Amazon_Web_Services', 'Babylon_Health', 'Microsoft', 'Epic_Records', 'Google'} | {'None'}
# Red Lobste | {'Red_Lobster', 'Thai_Union_Group'} | {'Red_Lobster'}
# Classic ’6 | {'None'} | {'Bespoke_tailoring'}
# New chip-p | {'Apple_Inc.', 'TSMC', 'Amkor_Technology'} | {'TSMC'}
# Euro zone  | {'None'} | {'None'}
# UiPath Non | {'None'} | {'None'}
# Billionair | {'UBS'} | {'None'}
# McDonald's | {"McDonald's"} | {'None'}
# McDonald's | {"McDonald's"} | {'None'}
# McDonald's | {'None'} | {'None'}
# McDonald's | {'None'} | {'None'}
# “Unrealize | {'None'} | {'None'}
# Warren Buf | {'Berkshire_Hathaway'} | {'Berkshire_Hathaway'}
# Chrysler B | {'Chrysler_Building', 'Signa'} | {'Chrysler_Building'}
# UAW Launch | {'Tesla,_Inc.', 'United_Automobile_Workers', 'Toyota', 'Rivian', 'Volkswagen'} | {'Toyota'}
# The Federa | {'Federal_Reserve'} | {'Federal_Reserve'}
# Roadrunner | {'None'} | {'None'}
# Pure Stora | {'Pure_Storage', 'Hewlett_Packard_Enterprise'} | {'None'}
# Okta: Brea | {'Okta'} | {'None'}
# Study says | {'None'} | {'None'}
# Gold price | {'None'} | {'None'}
# The long-e | {'VantageScore', 'British_Darts_Organisation', 'Dollar_Tree'} | {'None'}
# Stock mark | {'Texas_Instruments', 'Fixed–mobile_convergence', 'Zoetis', 'Thermo_Fisher_Scientific'} | {'None'}
# Electric V | {'Albemarle_County,_Virginia'} | {'None'}
# Natural Ga | {'None'} | {'None'}
# $1 Cash 5  | {'None'} | {'None'}
# A Gmail ou | {'None'} | {'None'}
# A certain  | {'Food_and_Drug_Administration'} | {'Food_and_Drug_Administration'}
# Salesforce | {'None'} | {'Salesforce.com'}
# Consumer R | {'None'} | {'Electric_vehicle'}
# Pending ho | {'None'} | {'None'}
# Forget the | {'Meta_Department', 'Google'} | {'None'}
# Defend aga | {'Amazon_(company)'} | {'None'}
# 'Disinflat | {'Albertsons', 'Express_Scripts', 'Ocado', 'Kroger'} | {'Kroger'}
# AI wars: A | {'Nvidia', 'Amazon_(company)', 'Anthropic_principle', 'Microsoft', 'JPMorgan_Chase', 'Google'} | {'Microsoft', 'Google'}
# AWS rolls  | {'Amazon_(company)', 'Microsoft'} | {'Amazon_Web_Services'}
# Live: Tesl | {'None'} | {'None'}
# Disney res | {'The_Walt_Disney_Company'} | {'Zazeh'}
# Target gif | {'None'} | {'None'}
# Dow rallie | {'Military_Committee_for_National_Recovery', 'Snowflake,_Arizona', 'Pinterest', 'The_Cowboy_Channel', 'Snap_Inc.', 'Salesforce.com', 'N_connector', 'Ford_Motor_Company'} | {'None'}
# Ulta Beaut | {"Macy's", 'Target_Corporation', 'Ulta_Beauty'} | {'Ulta'}
# European s | {'None'} | {'None'}
# Novo Nordi | {'Novo_Nordisk'} | {'Novo_Nordisk'}
# Novo Nordi | {'Novo_Nordisk'} | {'Novo_Nordisk'}
# Novo Nordi | {'Novo_Nordisk', 'Eli_Lilly'} | {'Novo_Nordisk'}
# Novo Nordi | {'Novo_Nordisk', 'Eli_Lilly'} | {'Novo_Nordisk'}
# Mortgage r | {'None'} | {'None'}
# Morning Bi | {'None'} | {'None'}
# Pending ho | {'None'} | {'None'}
# New $2 bil | {'Apple_Inc.', 'Amkor_Technology'} | {'Apple_Inc.'}
# Okta says  | {'Hewlett-Packard', 'FedEx', 'Caesars_Entertainment,_Inc.', 'T-Mobile', 'IBM', 'Paramount_Pictures', 'MGM_Resorts_International', 'Okta_(identity_management)'} | {'None'}
# Gilded Age | {'None'} | {'None'}
# History is | {'None'} | {'None'}
# Why you sh | {'Google'} | {'None'}
# Canada to  | {'Boeing', 'Bombardier_Aviation'} | {'None'}
# Tesla’s Cy | {'Tesla,_Inc.'} | {'None'}
# Why Oil Pr | {'OPEC'} | {'None'}
# USPS offer | {'United_States_Postal_Service'} | {'United_States_Postal_Service'}
# Ending soo | {'None'} | {'None'}
# Tegna Stat | {'NBC', 'Tegna_Inc.', 'Nexstar_Media_Group', 'Paramount_Television', 'Standard_General', 'CBS', 'Peafowl', 'DirecTV', 'AT&amp;T'} | {'NBC'}
# The Year T | {'JPMorgan_Chase', 'Farfetch', 'Richemont'} | {'None'}
# Disney Lin | {'Byron_Allen', 'Nexstar_Media_Group', 'The_Walt_Disney_Company', 'Charter_Communications'} | {'None'}
# US consume | {'None'} | {'None'}
# As salmone | {'None'} | {'Centers_for_Disease_Control_and_Prevention'}
# UAW Strike | {'Ford_Motor_Company'} | {'None'}
# AbbVie see | {'Daiichi_Sankyo', 'AstraZeneca', 'Equistone_Partners_Europe', 'ImmunoGen', 'Pfizer', 'SeaGen', 'Merck_&amp;_Co.', 'AbbVie_Inc.'} | {'AbbVie_Inc.'}
# Pending ho | {'National_Association_of_Realtors', 'Freddie_Mac'} | {'None'}
# Why you sh | {'None'} | {'None'}
# Mars, accu | {'Cargill', 'CBS', 'Nestlé', 'Mars', 'Mondelez_International'} | {'None'}
# New Califo | {'San_Diego_Gas_&amp;_Electric', 'Southern_California_Edison', 'Pacific_Gas_and_Electric_Company'} | {'None'}
# Morning Bi | {'None'} | {'None'}
# On ChatGPT | {'Amazon_(company)', 'Microsoft', 'Google', 'OpenAI'} | {'None'}
# Sam Altman | {'Salesforce.com', 'Quora', 'Microsoft', 'OpenAI'} | {'OpenAI'}
# Anduril’s  | {'None'} | {'None'}
# Bitcoin Ey | {'None'} | {'None'}
# Disney's I | {'The_Walt_Disney_Company'} | {'The_Walt_Disney_Company'}
# Putin Seiz | {'Baring_Vostok_Capital_Partners', 'Uniper', 'Fraport', 'VTB_Bank', 'Radio-frequency_identification', 'Qatar_Investment_Authority', 'Fortum'} | {'None'}
# Federal Re | {'Federal_Reserve'} | {'Federal_Reserve'}
# Gold Price | {'None'} | {'None'}
# Power to t | {'None'} | {'None'}
# Elon Musk  | {'Tesla,_Inc.'} | {'None'}
# Pfizer to  | {'Novo_Nordisk', 'Charles_Pfizer'} | {'Pfizer'}
# Bill Ackma | {'None'} | {'None'}
# The econom | {'None'} | {'None'}
# Bitcoin Ri | {'None'} | {'None'}
# Ford expec | {'Ford_Motor_Company'} | {'Ford_Motor_Company'}
# U.S. Senat | {'None'} | {'None'}
# Analysts S | {'None'} | {'None'}
# Anduril un | {'Middle-earth_weapons_and_armour'} | {'Middle-earth_weapons_and_armour'}
# Amtrak Fis | {'Amtrak'} | {'None'}
# Trailblaze | {'SpaceX', 'Tesla,_Inc.'} | {'None'}
# GDP may pa | {'None'} | {'None'}
# Asian stoc | {'None'} | {'None'}
# Morning Bi | {'Federal_Reserve'} | {'Federal_Reserve'}
# UAE seeks  | {'Brookfield,_Wisconsin', 'TPG_Telecom', 'BlackRock', 'Abu_Dhabi_National_Oil_Company'} | {'BlackRock'}
# Google beg | {'None'} | {'Google'}
# Why UiPath | {'UiPath'} | {'None'}
# Texas AG P | {'Pfizer'} | {'Pfizer'}
# Pfizer Ann | {"Programmer's_File_Editor", 'Pfizer'} | {'Pfizer'}
# OPEC+ memb | {'Petrobras', 'OPEC'} | {'OPEC'}
# Dow future | {'None'} | {'None'}
# These are  | {'None'} | {'Artificial_intelligence'}
# Red Lobste | {'Red_Lobster'} | {'Red_Lobster'}
# Stock mark | {'Federal_Reserve', 'OPEC'} | {'Federal_Reserve'}
# Candle Day | {'None'} | {'Bath_&amp;_Body_Works'}
# Microsoft  | {'Microsoft', 'OpenAI'} | {'Microsoft'}
# Solo passe | {'None'} | {'None'}
# Navigating | {'None'} | {'None'}
# Pennsylvan | {'Pennsylvania_Department_of_Health'} | {'Pennsylvania_Department_of_Health'}
# Apple and  | {'Apple_Inc.'} | {'Apple_Inc.'}
# Pfizer is  | {'Pfizer'} | {'Pfizer'}
# Haslam Fam | {'Berkshire_Hathaway', 'Aircraft_pilot'} | {'None'}
# Pfizer pul | {'Novo_Nordisk', 'Charles_Pfizer'} | {'Pfizer'}
# U.S. to Li | {'None'} | {'None'}
# Panera Bra | {'JPMorgan_Chase', 'Jab'} | {'None'}
# Why these  | {'Amphiphysin', 'Liquefied_petroleum_gas', 'Class_A_television_service', 'Otter_Tail_Corporation', 'South_Mississippi_Correctional_Institution', 'Reliance_Capital', 'SH2_domain', 'Adaptive_Multi-Rate_audio_codec', 'User_interface', 'U.S._Steel', 'Centrul_Național_Media', 'Ring-closing_metathesis'} | {'None'}
# First Move | {'None'} | {'None'}
# India's ec | {'None'} | {'DBS_Bank'}
# Tesla fall | {'Tesla,_Inc.'} | {'None'}
# Panera Bre | {'Krispy_Kreme', 'Yum!_Brands', 'JAB_Holding_Company', 'Panera_Bread'} | {'Panera_Bread'}
# Subway add | {'None'} | {'None'}
# Contrastin | {'None'} | {'None'}
# OpenAI mes | {'Microsoft', 'Quora'} | {'Microsoft', 'OpenAI'}
# Fisker Jus | {'None'} | {'None'}
# UPDATE 2-P | {'Pfizer'} | {'None'}
# Stocks mak | {'The_Walt_Disney_Company', 'Tesla,_Inc.', 'Ulta', 'Pfizer', 'Alibaba_Group', 'Coinbase', 'Marvell_Technology_Group', 'Elastic_NV', 'Dell'} | {'Pfizer', 'The_Walt_Disney_Company', 'Alibaba_Group', 'Tesla,_Inc.'}
# Broadcom C | {'VMware', 'Broadcom_Corporation'} | {'VMware', 'Broadcom_Corporation'}
# /tmp/ipykernel_472207/650356608.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"{row[1][2][:10]} | {row[1][6]} | {row[1][-1]}")
