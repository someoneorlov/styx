# %%
import numpy as np
import pandas as pd

# from newscatcher import Newscatcher, describe_url, urls
# from newspaper import Article
# from pygooglenews import GoogleNews
from gnews import GNews
# Out:
# /home/ec2-user/environments/styx_env/lib/python3.10/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.15) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %%
google_news = GNews(
    language='en', 
    country='US', 
    # period='365d', 
    # start_date=(2020, 1, 1), 
    # end_date=(2020, 1, 1), 
    # max_results=100, 
    # exclude_websites=['yahoo.com', 'cnn.com'],
    # proxy=proxy
)

# %%
from datetime import date, timedelta

# %%
# google_news.start_date = (2020, 1, 1) # Search from 1st Jan 2020
# google_news.end_date = (2020, 1, 1) # Search until 1st March 2020

# %%
start_date = date(2023, 9, 6)
end_date = date(2023, 9, 7)

# %%
news = []
while start_date < end_date:
    # Set the date and period
    google_news.start_date = (start_date.year, start_date.month, start_date.day)
    google_news.period = '1d'  # Period of 1 day

    # Get the news results
    results = google_news.get_news_by_topic('BUSINESS')
    
    # analyze the results, append them to a list, do whatever you need to do
    news += results

    # Increment the start date by 1 day
    start_date += timedelta(days=1)
# Out:
# /tmp/ipykernel_14795/1858835519.py:8: UserWarning: Only searches using the function get_news support date ranges. Review the documentation for get_news_by_topic for a partial workaround.
# Start date and end date will be ignored
#   results = google_news.get_news_by_topic('BUSINESS')
# /tmp/ipykernel_14795/1858835519.py:8: UserWarning:
# Period (1d) will be ignored in favour of the start and end dates
#   results = google_news.get_news_by_topic('BUSINESS')

# %%
news
# Out:
# [{'title': 'WeWork Looks to Renegotiate Most of Its Leases as It Fights to Survive - The Wall Street Journal',
#   'description': 'WeWork Looks to Renegotiate Most of Its Leases as It Fights to Survive  The Wall Street JournalWeWork Plans to Renegotiate Nearly All Leases  Bloomberg TelevisionWeWork Stock (WE) Jumps on Plan to Renegotiate Leases, Closing Some Locations  BloombergWeWork Declares Intent to Renegotiate Almost All Leases  The New York TimesWeWork tells landlords it will renegotiate most office leases  Financial TimesView Full Coverage on Google News',
#   'published date': 'Wed, 06 Sep 2023 23:06:00 GMT',
#   'url': 'https://news.google.com/rss/articles/CBMibGh0dHBzOi8vd3d3Lndzai5jb20vYXJ0aWNsZXMvd2V3b3JrLWxvb2tzLXRvLXJlbmVnb3RpYXRlLW1vc3Qtb2YtaXRzLWxlYXNlcy1hcy1pdC1maWdodHMtdG8tc3Vydml2ZS01YWQxYjBiM9IBAA?oc=5&hl=en-US&gl=US&ceid=US:en',
#   'publisher': {'href': 'https://www.wsj.com',
#    'title': 'The Wall Street Journal'}},
# ...

# %%
import sys

# %%
article.canonical_link
# Out:
# 'https://www.cnbc.com/2023/09/06/stocks-making-the-biggest-moves-after-hours-gme-aeo-chpt-ai.html'

# %%
feed_url = 'https://news.google.com/rss/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen'

# %%
import newspaper
import feedparser


def scrape_news_from_feed(feed_url):
    articles = []
    feed = feedparser.parse(feed_url)
    for i, entry in enumerate(feed.entries):
        print(i)
        # create a newspaper article object
        article = newspaper.Article(entry.link)
        # download and parse the article
        article.download()
        try:
            article.parse()
        except:
            err = sys.exc_info()
            for e in err:
                print(e)
            # print(f"{i}: Article `download()` failed with 451 Client Error: Unavailable For Legal Reasons for url'")
        # extract relevant information
        articles.append({
            'title': article.title,
            'author': article.authors,
            'publish_date': article.publish_date,
            'content': article.text
        })
    return articles


feed_url = feed_url
articles = scrape_news_from_feed(feed_url)

# print the extracted articles
for article in articles:
    print('Title:', article['title'])
    print('Author:', article['author'])
    print('Publish Date:', article['publish_date'])
    print('Content:', article['content'])
    print()
# Out:
# 0
# 1
# 2
# 3
# <class 'newspaper.article.ArticleException'>
# Article `download()` failed with ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer')) on URL https://news.google.com/rss/articles/CBMiKmh0dHBzOi8vd3d3LmJiYy5jb20vbmV3cy9idXNpbmVzcy02Njg3NDAxNtIBLmh0dHBzOi8vd3d3LmJiYy5jb20vbmV3cy9idXNpbmVzcy02Njg3NDAxNi5hbXA?oc=5
# ...
# 4
# <class 'newspaper.article.ArticleException'>
# Article `download()` failed with 403 Client Error: Forbidden for url: https://www.axios.com/2023/09/20/general-motors-stellantis-uaw-strike on URL https://news.google.com/rss/articles/CBMiRWh0dHBzOi8vd3d3LmF4aW9zLmNvbS8yMDIzLzA5LzIwL2dlbmVyYWwtbW90b3JzLXN0ZWxsYW50aXMtdWF3LXN0cmlrZdIBAA?oc=5
# ...
# 5
# <class 'newspaper.article.ArticleException'>
# ...

# %%
import newspaper
import feedparser


def scrape_news_from_feed(feed_url):
    articles = []
    feed = feedparser.parse(feed_url)
    for i, entry in enumerate(feed.entries):
        print(i)
        # create a newspaper article object
        article = newspaper.Article(entry.link)
        # download and parse the article
        article.download()
        try:
            article.parse()
        except newspaper.article.ArticleException:
            print(f"Can't parse source {entry['source']['href']}")
            print(f"{i}: Article `download()` failed with 451 Client Error: Unavailable For Legal Reasons for url'")
        # extract relevant information
        articles.append({
            'title': article.title,
            'author': article.authors,
            'publish_date': article.publish_date,
            'content': article.text
        })
    return articles


feed_url = feed_url
articles = scrape_news_from_feed(feed_url)

# print the extracted articles
for article in articles:
    print('Title:', article['title'])
    print('Author:', article['author'])
    print('Publish Date:', article['publish_date'])
    print('Content:', article['content'])
    print()

# %%
import newspaper
import feedparser


def scrape_news_from_feed(feed_url):
    articles = []
    feed = feedparser.parse(feed_url)
    for i, entry in enumerate(feed.entries):
        print(i)
        # create a newspaper article object
        article = newspaper.Article(entry.link)
        # download and parse the article
        article.download()
        try:
            article.parse()
        except Exception as err:
            print(err)
            # print(f"Can't parse source {entry['source']['href']}")
            # print(f"{i}: Article `download()` failed with 451 Client Error: Unavailable For Legal Reasons for url'")
        # extract relevant information
        articles.append({
            'title': article.title,
            'author': article.authors,
            'publish_date': article.publish_date,
            'content': article.text
        })
    return articles


feed_url = feed_url
articles = scrape_news_from_feed(feed_url)

# print the extracted articles
for article in articles:
    print('Title:', article['title'])
    print('Author:', article['author'])
    print('Publish Date:', article['publish_date'])
    print('Content:', article['content'])
    print()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# Article `download()` failed with 451 Client Error: Unavailable For Legal Reasons for url: https://www.koin.com/news/politics/oregon-attorney-general-suing-fox-news-over-misinformation/ on URL https://news.google.com/rss/articles/CBMiXmh0dHBzOi8vd3d3LmtvaW4uY29tL25ld3MvcG9saXRpY3Mvb3JlZ29uLWF0dG9ybmV5LWdlbmVyYWwtc3VpbmctZm94LW5ld3Mtb3Zlci1taXNpbmZvcm1hdGlvbi_SAQA?oc=5
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15
# Article `download()` failed with 429 Client Error: Unknown Error for url: https://thehill.com/policy/4201186-fda-warns-cvs-walgreens-other-companies-over-unapproved-eye-products/ on URL https://news.google.?oc=5
# 16
# 17
# 18
# 19
# 20
# 21
# 22
# ...

# %%
d = feedparser.parse(feed_url)

# %%
for key, value in d['entries'][0].items():
    print(key)
    print(value)
    print('=' * 10)
# Out:
# title
# Soft Core Inflation to Bolster Case Against More Fed Tightening - Bloomberg
# ...
# title_detail
# {'type': 'text/plain', 'language': None, 'base': 'https://news.google.com/rss/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGx6TVdZU0FtVnVHZ0pWVXlnQVAB?hl=en-US&gl=US&ceid=US%3Aen', 'value': 'Soft Core Inflation to Bolster Case Against More Fed Tightening - Bloomberg'}
# ...
# links
# [{'rel': 'alternate', 'type': 'text/html', 'href': 'https://news.google.com/rss/articles/CBMicmh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTA5LTEzL3NvZnQtY29yZS1pbmZsYXRpb24tdG8tYm9sc3Rlci1jYXNlLWFnYWluc3QtbW9yZS1mZWQtdGlnaHRlbmluZ9IBAA?oc=5'}]
# ...
# link
# https://news.google.com/rss/articles/CBMicmh0dHBzOi8vd3d3LmJsb29tYmVyZy5jb20vbmV3cy9hcnRpY2xlcy8yMDIzLTA5LTEzL3NvZnQtY29yZS1pbmZsYXRpb24tdG8tYm9sc3Rlci1jYXNlLWFnYWluc3QtbW9yZS1mZWQtdGlnaHRlbmluZ9IBAA?oc=5
# ...
# id
# 2394588462
# ...
# guidislink
# False
# ...
# published
# Wed, 13 Sep 2023 04:23:32 GMT
# ...
# published_parsed
# ...

# %%
from newspaper import Article

url = d['entries'][8]['link']
article = Article(url)

# %%
article.download()
article.parse()
# Out:
# ---------------------------------------------------------------------------
# ArticleException                          Traceback (most recent call last)
# Cell In[54], line 2
#       1 article.download()
# ----> 2 article.parse()
#
# File ~/environments/styx_env/lib/python3.10/site-packages/newspaper/article.py:191, in Article.parse(self)
#     190 def parse(self):
# --> 191     self.throw_if_not_downloaded_verbose()
#     193     self.doc = self.config.get_parser().fromstring(self.html)
#     194     self.clean_doc = copy.deepcopy(self.doc)
#
# File ~/environments/styx_env/lib/python3.10/site-packages/newspaper/article.py:531, in Article.throw_if_not_downloaded_verbose(self)
#     529     raise ArticleException('You must `download()` an article first!')
#     530 elif self.download_state == ArticleDownloadState.FAILED_RESPONSE:
# --> 531     raise ArticleException('Article `download()` failed with %s on URL %s' %
#     532           (self.download_exception_msg, self.url))
#
# ...

# %%
article.url
# Out:
# 'https://news.google.com/rss/articles/CBMiXmh0dHBzOi8vd3d3LmtvaW4uY29tL25ld3MvcG9saXRpY3Mvb3JlZ29uLWF0dG9ybmV5LWdlbmVyYWwtc3VpbmctZm94LW5ld3Mtb3Zlci1taXNpbmZvcm1hdGlvbi_SAQA?oc=5'

# %%
article.canonical_link

# %%
d['entries'][8]['source']['href']
# Out:
# 'https://www.koin.com'

# %%
article = newspaper.Article(feed.entries[7].link)

# %%
gn = GoogleNews()

# %%
top = gn.top_news()

# %%
business = gn.topic_headlines('BUSINESS', proxies=None, scraping_bee = None, )

# %%
len(business['entries'])
# Out:
# 69

# %%
search = gn.search('', when = '6m')

# %%
len(search['entries'])
# Out:
# 98

# %%
search['entries']
# Out:
# [{'title': 'The K7RA Solar Update - ARRL',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': 'The K7RA Solar Update - ARRL'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://news.google.com/rss/articles/CBMiMmh0dHA6Ly93d3cuYXJybC5vcmcvbmV3cy90aGUtazdyYS1zb2xhci11cGRhdGUtNzY30gEA?oc=5'}],
#   'link': 'https://news.google.com/rss/articles/CBMiMmh0dHA6Ly93d3cuYXJybC5vcmcvbmV3cy90aGUtazdyYS1zb2xhci11cGRhdGUtNzY30gEA?oc=5',
#   'id': 'CBMiMmh0dHA6Ly93d3cuYXJybC5vcmcvbmV3cy90aGUtazdyYS1zb2xhci11cGRhdGUtNzY30gEA',
#   'guidislink': False,
#   'published': 'Fri, 03 Mar 2023 19:17:48 GMT',
#   'published_parsed': time.struct_time(tm_year=2023, tm_mon=3, tm_mday=3, tm_hour=19, tm_min=17, tm_sec=48, tm_wday=4, tm_yday=62, tm_isdst=0),
# ...

# %%
english_business_urls = urls(topic = 'business', language = 'en') 
english_business_urls
# Out:
# ['economist.com',
#  'fortune.com',
#  'inc.com',
#  'entrepreneur.com',
#  'weforum.org',
#  'mckinsey.com',
#  'businessinsider.de',
#  'globenewswire.com',
#  'foxbusiness.com',
#  'hbs.edu',
#  'business-standard.com',
#  'rediff.com',
#  'moneycontrol.com',
#  'arabianbusiness.com',
#  'bloombergquint.com',
#  'insead.edu',
#  'businesstoday.in',
#  'blackenterprise.com',
#  'strategy-business.com',
#  'openpr.com',
#  'forbesindia.com',
#  'euromoney.com',
#  'biv.com',
#  'nbr.co.nz',
#  'dealstreetasia.com',
#  'calculatedriskblog.com',
#  'worth.com',
#  'investegate.co.uk',
#  'dynamicbusiness.com.au',
#  'growthbusiness.co.uk',
#  'businessmanagementdaily.com',
#  'brinknews.com',
#  'ukbusinessforums.co.uk',
#  'sharenet.co.za',
#  'vbjusa.com',
#  'kochiesbusinessbuilders.com.au',
#  'sharechat.co.nz']

# %%
https://www.reuters.com

# %%
news_source = 'economist.com'

# %%
nc = Newscatcher(website=news_source)
results = nc.get_news()

# %%
describe = describe_url(news_source)

describe
# Out:
# {'url': 'fortune.com',
#  'language': 'en',
#  'country': 'US',
#  'main_topic': 'business',
#  'topics': ['tech', 'business']}

# %%
nc = Newscatcher(website=news_source, topic='business')

results = nc.get_news()
articles = results['articles']

# %%
len(articles)
# Out:
# 10

# %%
articles[0]
# Out:
# {'title': "Digging out some Californians from epic blizzard could take a week: 'The enormity of this event is hard to comprehend'",
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://fortune.com/feed/fortune-feeds/?id=3230629',
#   'value': "Digging out some Californians from epic blizzard could take a week: 'The enormity of this event is hard to comprehend'"},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://fortune.com/2023/03/03/californian-blizzard-snow/'}],
#  'link': 'https://fortune.com/2023/03/03/californian-blizzard-snow/',
#  'published': 'Sat, 04 Mar 2023 02:41:46 +0000',
#  'published_parsed': time.struct_time(tm_year=2023, tm_mon=3, tm_mday=4, tm_hour=2, tm_min=41, tm_sec=46, tm_wday=5, tm_yday=63, tm_isdst=0),
#  'authors': [{'name': 'John Antczak, Bloomberg'}],
#  'author': 'John Antczak, Bloomberg',
#  'author_detail': {'name': 'John Antczak, Bloomberg'},
# ...

# %%
articles[0]['title']
# Out:
# "Digging out some Californians from epic blizzard could take a week: 'The enormity of this event is hard to comprehend'"

# %%
articles[0]['summary']
# Out:
# 'Extraordinary snowfall\xa0buried homes and businesses, overwhelming the capability of snowplowing equipment geared toward ordinary storms.'

# %%
articles[0]['link']
# Out:
# 'https://fortune.com/2023/03/03/californian-blizzard-snow/'

# %%
articles[0]['published_parsed']
# Out:
# time.struct_time(tm_year=2023, tm_mon=3, tm_mday=4, tm_hour=2, tm_min=41, tm_sec=46, tm_wday=5, tm_yday=63, tm_isdst=0)

# %%
articles[0]['tags']
# Out:
# [{'term': 'U.S.', 'scheme': None, 'label': None}]

# %%
articles[0]['authors']
# Out:
# [{'name': 'John Antczak, Bloomberg'}]

# %%
url = articles[0]['link']
article = Article(url)

# %%
article.download()
article.parse()

# %%
article.authors
# Out:
# ['John Antczak Bloomberg']

# %%
article.publish_date
# Out:
# datetime.datetime(2023, 3, 3, 0, 0)

# %%
article.text
# Out:
# 'Some residents stranded in Southern California mountain communities by a huge snowfall could be stuck for another week, an official said Friday.\n\nA late-February blast of arctic air produced a rare blizzard east of Los Angeles in the San Bernardino Mountains, where thousands of people live at high elevations in forest communities or visit for year-round recreation.\n\nExtraordinary snowfall buried homes and businesses, overwhelming the capability of snowplowing equipment geared toward ordinary storms.\n\nBy last weekend, all highways leading up into the mountains were closed and have opened intermittently since then to residents and convoys of trucks loaded with food or other supplies.\n\nThe estimate by San Bernardino County Sheriff Shannon Dicus was an improvement in the outlook for stranded residents, which previously ranged up to two weeks.\n\n“We’ve said we could push it out as far as two weeks but because of the state’s efforts and the equipment that’s coming in behind us we
# ...

# %%
article.top_image
# Out:
# 'https://content.fortune.com/wp-content/uploads/2023/03/GettyImages-1470850338.jpg?resize=1200,600'

# %%
article.nlp()

# %%
article.keywords
# Out:
# ['snow',
#  'comprehend',
#  'state',
#  'san',
#  'californians',
#  'residents',
#  'homes',
#  'event',
#  'epic',
#  'street',
#  'california',
#  'hard',
#  'enormity',
#  'county',
#  'digging',
#  'blizzard',
#  'bernardino',
#  'mountains',
#  'week']

# %%
article.summary
# Out:
# 'A late-February blast of arctic air produced a rare blizzard east of Los Angeles in the San Bernardino Mountains, where thousands of people live at high elevations in forest communities or visit for year-round recreation.\nThe estimate by San Bernardino County Sheriff Shannon Dicus was an improvement in the outlook for stranded residents, which previously ranged up to two weeks.\n“The enormity of this event is hard to comprehend,” said state Assemblyman Tom Lackey.\nResidents and vacationers trapped in the San Bernardino range have taken to social media to show their plight and wonder when plows are coming.\nAbout 80,000 people live in the San Bernardino Mountains either part or full time.'

# %%
from newscatcherapi import NewsCatcherApiClient

# %%
API_KEY = '0Ed5lK8R7hyhvwO9_8Tf_GbbiwieUjW_J3tw5r8jRRw'
newscatcherapi = NewsCatcherApiClient(x_api_key=API_KEY)
news_articles = newscatcherapi.get_search(q='apple', sources=news_source)

# %%
API_KEY = '0Ed5lK8R7hyhvwO9_8Tf_GbbiwieUjW_J3tw5r8jRRw'
newscatcherapi = NewsCatcherApiClient(x_api_key=API_KEY)
news_articles = newscatcherapi.get_search(topic='business', sources=news_source)
# Out:
# ---------------------------------------------------------------------------
# NewsCatcherApiException                   Traceback (most recent call last)
# /var/folders/0z/s79f70bs7w5gq9dxf9sbnqrh0000gn/T/ipykernel_16095/4146229267.py in <module>
#       1 API_KEY = '0Ed5lK8R7hyhvwO9_8Tf_GbbiwieUjW_J3tw5r8jRRw'
#       2 newscatcherapi = NewsCatcherApiClient(x_api_key=API_KEY)
# ----> 3 news_articles = newscatcherapi.get_search(topic='business', sources=news_source)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/newscatcherapi/newscatcherapi_client.py in get_search(self, q, lang, not_lang, from_, to_, published_date_precision, search_in, countries, not_countries, topic, sources, not_sources, ranked_only, from_rank, to_rank, sort_by, page_size, page, proxies)
#     378         # Check Status of Request
#     379         if r.status_code != requests.codes.ok:
# --> 380             raise NewsCatcherApiException(r.json())
#     381
#     382         return r.json()
#
# ...

# %%
len(newscatcherapi.get_latest_headlines(sources=news_source))
# Out:
# 7

# %%
temp = newscatcherapi.get_latest_headlines_all_pages(sources=news_source, when='24h')
# Out:
# 1 page is going to be extracted
# Total number of found articles => 73.
# Total number of pages 1.

# %%
383 * 52
# Out:
# 19916

# %%
73 * 365
# Out:
# 26645

# %%
temp['articles'][0]
# Out:
# {'title': "Digging out some Californians from epic blizzard could take a week: ‘The enormity of this event is hard to comprehend'",
#  'author': 'John Antczak Bloomberg',
#  'published_date': '2023-03-04 02:41:46',
#  'published_date_precision': 'full',
#  'link': 'https://fortune.com/2023/03/03/californian-blizzard-snow/',
#  'clean_url': 'fortune.com',
#  'excerpt': 'Extraordinary snowfall buried homes and businesses, overwhelming the capability of snowplowing equipment geared toward ordinary storms.',
# ...

# %%
df = pd.read_csv('Downloads/bloomberg_biz_sitemap.csv')
# Out:
# /var/folders/0z/s79f70bs7w5gq9dxf9sbnqrh0000gn/T/ipykernel_17741/1611612555.py:1: DtypeWarning: Columns (1,2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Downloads/bloomberg_biz_sitemap.csv')

# %%
df.head()
# Out:
#                                                  loc  \
# 0  https://www.bloomberg.com/news/articles/2020-0...
# 1  https://www.bloomberg.com/news/articles/2020-0...
# 2  https://www.bloomberg.com/news/articles/2020-0...
# 3  https://www.bloomberg.com/news/articles/2020-0...
# 4  https://www.bloomberg.com/news/articles/2020-0...
#
#                             lastmod changefreq  priority  \
# 0  2020-03-31 01:27:21.976000+00:00     always       1.0
# 1  2020-03-31 01:19:59.078000+00:00     always       1.0
# 2  2020-03-31 01:09:15.292000+00:00     always       1.0
# 3  2020-03-31 01:05:37.752000+00:00     always       1.0
# 4  2020-03-31 00:51:43.236000+00:00     always       1.0
#
#                                            alternate  \
# 0  android-app://com.bloomberg.android.plus/bbg-a...
# 1  android-app://com.bloomberg.android.plus/bbg-a...
# 2  android-app://com.bloomberg.android.plus/bbg-a...
# 3  android-app://com.bloomberg.android.plus/bbg-a...
# ...

# %%
df['loc'][0]
# Out:
# 'https://www.bloomberg.com/news/articles/2020-03-30/working-from-home-gives-chipmakers-a-boost-while-others-suffer'

# %%
url = df['loc'][0]
article = Article(url)

# %%
article.download()
article.parse()

# %%
article.authors
# Out:
# ['Kyoungwha Kim',
#  'Heejin Kim',
#  'Kyoungwha Kim Heejin Kim',
#  'Follow The Authors']

# %%
article.publish_date
# Out:
# datetime.datetime(2020, 3, 30, 0, 0)

# %%
article.text
# Out:
# 'Prognosis\n\nPrognosis explores health, wellness, and the ways in which modern science is allowing us to live better - in both the long term, and day-to-day'

# %%
df = pd.read_csv('Downloads/cnbc_news_datase.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0  Santoli’s Wednesday market notes: Could Septem...
# 1     My take on the early Brexit winners and losers
# 2  Europe&#039;s recovery depends on Renzi&#039;s...
# 3  US Moves Closer to Becoming A Major Shareholde...
# 4  Trump: 'Mission accomplished' on 'perfectly ex...
#
#                                                  url  \
# 0  https://www.cnbc.com/2021/09/29/santolis-wedne...
# 1  https://www.cnbc.com/2016/06/24/ian-bremmers-t...
# 2  https://www.cnbc.com/2014/03/25/europes-recove...
# 3  https://www.cnbc.com/2009/04/22/us-moves-close...
# 4  https://www.cnbc.com/2018/04/14/trump-mission-...
#
#                published_at                   author publisher  \
# 0  2021-09-29T17:09:39+0000          Michael Santoli      CNBC
# 1  2016-06-24T13:50:48-0400                      NaN      CNBC
# 2  2014-03-25T13:29:45-0400                      NaN      CNBC
# 3  2009-04-22T19:49:03+0000  Michelle Caruso-Cabrera      CNBC
# ...

# %%
df.shape
# Out:
# (625, 11)

# %%
df.loc[0, 'title']
# Out:
# 'Santoli’s Wednesday market notes: Could September’s stock shakeout tee up strength for the fourth quarter?'

# %%
df.loc[0, 'description']
# Out:
# "This is the daily notebook of Mike Santoli, CNBC's senior markets commentator, with ideas about trends, stocks and market statistics.A muted, inconclusive bounce that has left the indexes fully within yesterday's low-to-high range all morning so far."

# %%
df.loc[0, 'url']
# Out:
# 'https://www.cnbc.com/2021/09/29/santolis-wednesday-market-notes-could-septembers-stock-shakeout-tee-up-strength-for-the-fourth-quarter.html'

# %%
url = df.loc[1, 'url']
article = Article(url)

# %%
article.download()
article.parse()

# %%
article.authors
# Out:
# ['Ian Bremmer', 'President Of The Eurasia Group', 'Dylan Martinez']

# %%
article.publish_date
# Out:
# datetime.datetime(2016, 6, 24, 0, 0)

# %%
article.text
# Out:
# 'Boris Johnson – The former London mayor and grudging "Leave" supporter-turned enthusiastic "Leave" leader chose the winning side. He\'s now a front-runner to lead the Tory party. \u202a#\u200eHellFreezesOver\u202c\n\nTheresa May – Boris Johnson\'s populist approach to the Brexit campaign ticked off quite a few Tory elders, so the real money should be on UK Home Secretary Theresa May to succeed outgoing Prime Minister David Cameron. May is a political heavyweight and is generally respected among the Tories, something Boris Johnson is … um, not.\n\nNigel Farage – the once-embattled UK Independence Party leader gets his moment in the sun. Also gets to keep having a political career. And the fact that he quoted "Independence Day" in his victory speech made a crazy night that much crazier.\n\nMarine Le Pen/Geert Wilders – Charismatic figures with a long history agitating for EU exits, France\'s Marine Le Pen and the Netherlands\' Geert Wilders wasted no time calling for their own referen
# ...

# %%
df['published_at'].min()
# Out:
# '2006-12-04T19:51:48+0000'

# %%
df['published_at'].max()
# Out:
# '2021-10-18T08:00:25+0000'

# %%
df = pd.read_csv('Downloads/archive/cnbc_headlines.csv')

# %%
df.head()
# Out:
#                                            Headlines  \
# 0  Jim Cramer: A better way to invest in the Covi...
# 1     Cramer's lightning round: I would own Teradyne
# 2                                                NaN
# 3  Cramer's week ahead: Big week for earnings, ev...
# 4  IQ Capital CEO Keith Bliss says tech and healt...
#
#                              Time  \
# 0   7:51  PM ET Fri, 17 July 2020
# 1   7:33  PM ET Fri, 17 July 2020
# 2                             NaN
# 3   7:25  PM ET Fri, 17 July 2020
# 4   4:24  PM ET Fri, 17 July 2020
#
#                                          Description
# 0  "Mad Money" host Jim Cramer recommended buying...
# 1  "Mad Money" host Jim Cramer rings the lightnin...
# 2                                                NaN
# 3  "We'll pay more for the earnings of the non-Co...
# 4  Keith Bliss, IQ Capital CEO, joins "Closing Be...

# %%
df.shape
# Out:
# (3080, 3)

# %%
df = pd.read_csv('Downloads/archive/reuters_headlines.csv')

# %%
df.head()
# Out:
#                                            Headlines         Time  \
# 0  TikTok considers London and other locations fo...  Jul 18 2020
# 1  Disney cuts ad spending on Facebook amid growi...  Jul 18 2020
# 2  Trail of missing Wirecard executive leads to B...  Jul 18 2020
# 3  Twitter says attackers downloaded data from up...  Jul 18 2020
# 4  U.S. Republicans seek liability protections as...  Jul 17 2020
#
#                                          Description
# 0  TikTok has been in discussions with the UK gov...
# 1  Walt Disney  has become the latest company to ...
# 2  Former Wirecard  chief operating officer Jan M...
# 3  Twitter Inc said on Saturday that hackers were...
# 4  A battle in the U.S. Congress over a new coron...

# %%
df.shape
# Out:
# (32770, 3)
